# %% [markdown]
# # Twitter Stream Launcher

# %%
import requests
import os
import json

# To set your enviornment variables in your terminal run the following line:
# export 'BEARER_TOKEN'='<your_bearer_token>'

bearer_token = 'AAAAAAAAAAAAAAAAAAAAAAGrcgEAAAAAZtB52qT%2F9wwlHjjnh1O20JLqqwo%3DpP6id6DjjZDU3kM6YPo513aAtQzo9ymFexWUxfBcxRfprbVAqE'


def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2FilteredStreamPython"
    return r


def get_rules():
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream/rules", auth=bearer_oauth
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot get rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))
    return response.json()


def delete_all_rules(rules):
    if rules is None or "data" not in rules:
        return None

    ids = list(map(lambda rule: rule["id"], rules["data"]))
    payload = {"delete": {"ids": ids}}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        auth=bearer_oauth,
        json=payload
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot delete rules (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    print(json.dumps(response.json()))


def set_rules(delete):
    # You can adjust the rules if needed
    sample_rules = [
        {"value": ' "Love is" lang:en -is:retweet -has:images -has:media -has:mentions -has:links -has:hashtags'}
    ]
    payload = {"add": sample_rules}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        auth=bearer_oauth,
        json=payload,
    )
    if response.status_code != 201:
        raise Exception(
            "Cannot add rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))


def get_stream(set):
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream", auth=bearer_oauth, stream=True, 
    )
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Cannot get stream (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    for response_line in response.iter_lines():
        if response_line:
            json_response = json.loads(response_line)
            with open('streaming_NLP_Bag_Of_Words.txt', 'a') as f:
                if len(json_response["data"]["text"])<25:
                    print(json_response["data"]["text"], file=f)
                if len(open('streaming_NLP_Bag_Of_Words.txt').readlines(  )) > 200:
                        break
            print(json.dumps(json_response, indent=4, sort_keys=True))


def main():
    rules = get_rules()
    delete = delete_all_rules(rules)
    set = set_rules(delete)
    get_stream(set)
    
if __name__ == "__main__":
    main()
# Out:
# {"data": [{"id": "1547645221118234628", "value": " \"Love is\" lang:en -is:retweet -has:images -has:media -has:mentions -has:links -has:hashtags"}], "meta": {"sent": "2022-07-15T16:16:47.966Z", "result_count": 1}}
# {"meta": {"sent": "2022-07-15T16:16:48.442Z", "summary": {"deleted": 1, "not_deleted": 0}}}
# {"data": [{"value": " \"Love is\" lang:en -is:retweet -has:images -has:media -has:mentions -has:links -has:hashtags", "id": "1547978499176034306"}], "meta": {"sent": "2022-07-15T16:16:48.928Z", "summary": {"created": 1, "not_created": 0, "valid": 1, "invalid": 0}}}
# 200
# {
#     "data": {
#         "id": "1547978498341384195",
#         "text": "Integral to as sunlight drinketh dew. You are only accidents. True love is\n\u0646\u0645\u0634\u06d2\n\n\ud83c\udf97\ufe0fKC30\ud83c\udf97\ufe0f\n\ud83c\udf97\ufe0fKC30\ud83c\udf97\ufe0f\n\u061f?"
#     },
#     "matching_rules": [
#         {
#             "id": "1547645221118234628",
#             "tag": ""
#         }
#     ]
# }
# ...

# %% [markdown]
# Problems of BOW approach:
# 1. https://www.researchgate.net/publication/292943899_Enhancement_Bag-of-Words_Model_for_Solving_the_Challenges_of_Sentiment_Analysis
# 2. https://arxiv.org/pdf/2004.06800.pdf
